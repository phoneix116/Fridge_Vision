# %%
# !pip -q install roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 65.1 MB/s eta 0:00:00

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="39VEjqC54eLDMKL0gi9Y")
project = rf.workspace("steph-r3xmc").project("combined-dataset-3n32l")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Combined-dataset-5 to yolov11:: 100%|██████████| 255472/255472 [00:07<00:00, 33544.31it/s]
# Extracting Dataset Version Zip to Combined-dataset-5 in yolov11:: 100%|██████████| 10946/10946 [00:02<00:00, 4517.29it/s]

# %%
print(dataset.location)
# Out:
# /content/Combined-dataset-5

# %%
# !pip -q install ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.6 MB/s eta 0:00:00

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.4.21

# %%
from ultralytics import YOLO

model = YOLO("yolo11l.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11l.pt to 'yolo11l.pt': 100% ━━━━━━━━━━━━ 49.0MB 138.0MB/s 0.4s

# %%
model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=40,
    imgsz=800,
    batch=8,
    mosaic=1.0,
    iou=0.6,
    device=0,
    workers=8
)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Combined-dataset-5/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=800, int8=False, iou=0.6, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11l.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 13.3MB/s 0.1s
# Overriding model.yaml nc=80 with nc=67
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1462681  ultralytics.nn.modules.head.Detect           [67, 16, None, [256, 512, 512]]
# YOLO11l summary: 358 layers, 25,362,137 parameters, 25,362,121 gradients, 87.6 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 53.7MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1238.8±602.2 MB/s, size: 43.7 KB)
# train: Scanning /content/Combined-dataset-5/train/labels... 4504 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4504/4504 2.1Kit/s 2.1s
# train: New cache created: /content/Combined-dataset-5/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 18, len(boxes) = 31824. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 396.2±355.8 MB/s, size: 45.7 KB)
# val: Scanning /content/Combined-dataset-5/valid/labels... 641 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 641/641 1.0Kit/s 0.6s
# val: New cache created: /content/Combined-dataset-5/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000141, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0005), 173 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train/labels.jpg...
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      7.98G      1.037      1.634      1.132         77        800: 100% ━━━━━━━━━━━━ 563/563 1.3it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 1.5it/s 26.6s
#                    all        641       4631      0.798      0.491      0.532      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      8.23G     0.9482     0.7598      1.094         87        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.6s
#                    all        641       4631      0.643      0.606      0.623       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      8.12G     0.9297     0.6757      1.089         82        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.3s
#                    all        641       4631      0.678      0.637      0.686      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      8.13G     0.9163     0.6309      1.087         67        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.8s
#                    all        641       4631      0.656      0.705      0.729      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      8.21G     0.8912     0.5852      1.075         84        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.6s
#                    all        641       4631      0.748      0.708      0.762      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      8.22G      0.882     0.5609      1.071         88        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.4s
#                    all        641       4631      0.701      0.746       0.77      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      8.22G     0.8753     0.5473      1.072         83        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.3s
#                    all        641       4631      0.769      0.731      0.782      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      8.21G     0.8636     0.5211      1.066         61        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.759      0.755      0.796      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      8.22G     0.8556     0.5082       1.06        111        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.6s
#                    all        641       4631      0.744      0.762      0.796      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40       8.2G     0.8342     0.4957      1.052         82        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.7s
#                    all        641       4631      0.776      0.756      0.801      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      8.23G     0.8215     0.4778      1.046        138        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.4s
#                    all        641       4631      0.804      0.785       0.84      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      8.13G     0.8135     0.4693      1.041         44        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.2s
#                    all        641       4631      0.845      0.756      0.846      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      8.22G     0.8094     0.4598       1.04        108        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.809      0.818      0.846      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      8.21G      0.794     0.4531      1.032         80        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.2s
#                    all        641       4631      0.804      0.789       0.84      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      8.21G      0.784     0.4393      1.028         71        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.2s
#                    all        641       4631      0.829      0.768       0.85      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      8.25G      0.784     0.4328      1.028         85        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.2s
#                    all        641       4631      0.833      0.767      0.835      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      8.25G     0.7684     0.4227      1.023         64        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.803      0.838      0.845       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      8.22G      0.768     0.4192      1.022         73        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.7s
#                    all        641       4631      0.815      0.798      0.844      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      8.21G     0.7521     0.4073      1.014         76        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.4s
#                    all        641       4631      0.863      0.804      0.856      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      8.12G     0.7468     0.4045      1.014         87        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.7s
#                    all        641       4631       0.83      0.837      0.855      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      8.22G     0.7362     0.3926      1.006        133        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.7s
#                    all        641       4631      0.856      0.801      0.858      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      8.23G     0.7302     0.3866      1.005         83        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.6s
#                    all        641       4631      0.841      0.809      0.854      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      8.22G     0.7194     0.3802     0.9978         94        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.7s
#                    all        641       4631      0.861      0.826      0.855      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      8.22G     0.7177     0.3775     0.9979         72        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631       0.84      0.819      0.858      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      8.21G     0.7047     0.3679     0.9901         76        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.859      0.816      0.857      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      8.22G     0.7016     0.3647     0.9915         57        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.9s
#                    all        641       4631      0.867      0.808      0.857      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      8.25G     0.6975     0.3601     0.9869        100        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.4s
#                    all        641       4631      0.846      0.844      0.855      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      8.11G     0.6855     0.3542     0.9852         96        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.852      0.836      0.861      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      8.27G     0.6734     0.3514      0.976        119        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.3s
#                    all        641       4631      0.864      0.834      0.866      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      8.22G     0.6738     0.3449       0.98         71        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.869      0.838      0.865      0.692
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40       8.2G     0.6234     0.2961     0.9697         52        800: 100% ━━━━━━━━━━━━ 563/563 1.4it/s 6:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 2.1it/s 19.5s
#                    all        641       4631      0.874      0.835      0.859      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40       8.2G     0.6028     0.2913     0.9546         55        800: 19% ━━────────── 105/563 2.1it/s 1:15<3:34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_265/1365922912.py in <cell line: 0>()
# ----> 1 model.train(
#       2     data=f"{dataset.location}/data.yaml",
#       3     epochs=40,
#       4     imgsz=800,
#       5     batch=8,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     775             self.model = self.trainer.model
#     776
# --> 777         self.trainer.train()
#     778         # Update model and cfg after training
#     779         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     242
#     243         else:
# --> 244             self._do_train()
#     245
#     246     def _setup_scheduler(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _do_train(self)
#     434                             loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     435                         else:
# --> 436                             loss, self.loss_items = self.model(batch)
#     437                         self.loss = loss.sum()
#     438                         if RANK != -1:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     139         """
#     140         if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141             return self.loss(x, *args, **kwargs)
#     142         return self.predict(x, *args, **kwargs)
#     143
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in loss(self, batch, preds)
#     333         if preds is None:
#     334             preds = self.forward(batch["img"])
# --> 335         return self.criterion(preds, batch)
#     336
#     337     def init_criterion(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py in __call__(self, preds, batch)
#     460     ) -> tuple[torch.Tensor, torch.Tensor]:
#     461         """Calculate the sum of the loss for box, cls and dfl multiplied by batch size."""
# --> 462         return self.loss(self.parse_output(preds), batch)
#     463
#     464     def loss(self, preds: dict[str, torch.Tensor], batch: dict[str, torch.Tensor]) -> tuple[torch.Tensor, torch.Tensor]:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py in loss(self, preds, batch)
#     465         """Calculate detection loss using assigned targets."""
#     466         batch_size = preds["boxes"].shape[0]
# --> 467         loss, loss_detach = self.get_assigned_targets_and_loss(preds, batch)[1:]
#     468         return loss * batch_size, loss_detach
#     469
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py in get_assigned_targets_and_loss(self, preds, batch)
#     396             preds["scores"].permute(0, 2, 1).contiguous(),
#     397         )
# --> 398         anchor_points, stride_tensor = make_anchors(preds["feats"], self.stride, 0.5)
#     399
#     400         dtype = pred_scores.dtype
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/tal.py in make_anchors(feats, strides, grid_cell_offset)
#     409         sy, sx = torch.meshgrid(sy, sx, indexing="ij") if TORCH_1_11 else torch.meshgrid(sy, sx)
#     410         anchor_points.append(torch.stack((sx, sy), -1).view(-1, 2))
# --> 411         stride_tensor.append(torch.full((h * w, 1), stride, dtype=dtype, device=device))
#     412     return torch.cat(anchor_points), torch.cat(stride_tensor)
#     413
#
# KeyboardInterrupt:

# %%
from google.colab import files

files.download("runs/detect/train/weights/best.pt")
